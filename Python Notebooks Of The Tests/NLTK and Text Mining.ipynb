# %%
import os
import nltk
import nltk.corpus

# %%
print(os.listdir(nltk.data.find('corpora')))
# Out:
# ['abc', 'abc.zip', 'alpino', 'alpino.zip', 'biocreative_ppi', 'biocreative_ppi.zip', 'brown', 'brown.zip', 'brown_tei', 'brown_tei.zip', 'cess_cat', 'cess_cat.zip', 'cess_esp', 'cess_esp.zip', 'chat80', 'chat80.zip', 'city_database', 'city_database.zip', 'cmudict', 'cmudict.zip', 'comparative_sentences', 'comparative_sentences.zip', 'comtrans.zip', 'conll2000', 'conll2000.zip', 'conll2002', 'conll2002.zip', 'conll2007.zip', 'crubadan', 'crubadan.zip', 'dependency_treebank', 'dependency_treebank.zip', 'dolch', 'dolch.zip', 'europarl_raw', 'europarl_raw.zip', 'floresta', 'floresta.zip', 'framenet_v15', 'framenet_v15.zip', 'framenet_v17', 'framenet_v17.zip', 'gazetteers', 'gazetteers.zip', 'genesis', 'genesis.zip', 'gutenberg', 'gutenberg.zip', 'ieer', 'ieer.zip', 'inaugural', 'inaugural.zip', 'indian', 'indian.zip', 'jeita.zip', 'kimmo', 'kimmo.zip', 'knbc.zip', 'lin_thesaurus', 'lin_thesaurus.zip', 'machado.zip', 'mac_morpho', 'mac_morpho.zip', 'masc_tagged.zip', 'movie_reviews', 'mov
# ...

# %%
hamlet = nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')

# %%
hamlet
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
for word in hamlet[:1000]:
    print(word, sep= ' ',end =' ')
# Out:
# [ The Tragedie of Hamlet by William Shakespeare 1599 ] Actus Primus . Scoena Prima . Enter Barnardo and Francisco two Centinels . Barnardo . Who ' s there ? Fran . Nay answer me : Stand & vnfold your selfe Bar . Long liue the King Fran . Barnardo ? Bar . He Fran . You come most carefully vpon your houre Bar . ' Tis now strook twelue , get thee to bed Francisco Fran . For this releefe much thankes : ' Tis bitter cold , And I am sicke at heart Barn . Haue you had quiet Guard ? Fran . Not a Mouse stirring Barn . Well , goodnight . If you do meet Horatio and Marcellus , the Riuals of my Watch , bid them make hast . Enter Horatio and Marcellus . Fran . I thinke I heare them . Stand : who ' s there ? Hor . Friends to this ground Mar . And Leige - men to the Dane Fran . Giue you good night Mar . O farwel honest Soldier , who hath relieu ' d you ? Fra . Barnardo ha ' s my place : giue you goodnight . Exit Fran . Mar . Holla Barnardo Bar . Say , what is Horatio there ? Hor . A peece of him Ba
# ...

# %%
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
data_in = """ Natural Language Started as a Project for Translating Languages Mainly Russian in to English in 1950’s. Then in 1954 in a Demonstrating by IBM they converted 60 Russian Sentences to English using IBM-701 computer. The Method they used was Computational Linguistics a Combination of Statistics and Rules of Language.  In 1956 in a Conference that were held in Dartmouth College, New Hampshire, England John McCarthy coined the Term ‘Artificial Intelligence’. So Natural Language Processing was introduced in the early stages of Artificial Intelligence and Computers. Another one of the Main changing point in History of NLP is in 1957, Noam Chomsky published the book Syntactic Structures in which he revolutionized previous linguistics concepts and he invented a type of grammar titled “Phase-Structure” Grammar that systematically converted natural language sentences to a form usable by computers. 
In this Era NLP was done by creating hand written rules to Translate text from one language to a another. And Computer programming was also in a privative stage. Then, in 1958, John McCarthy released the programming language LISP: Locator/Identifier Separation Protocol. Which again created a boom in computer research because now the researches had a platform to work on a language that they can code on to create the systems they needed. One of the early NLP systems was ELIZA. ELIZA was created in 1964 and, by only rearranging sentences and following some relatively simple grammar rules, impersonated a psychiatrist.
The United States National Research Council (NRC) for short, founded the Automatic Language Processing Advisory Committee (ALPAC) in 1964 that was assigned to evaluate the progress of NLP research. But during this era it seemed that the NLP research was coming to a halt due to hardware limitations and less improvements in approaches to NLP. So After reaching in dying state in the 1960s, NLP/MT got a new life when the idea and need of Artificial Intelligence emerged. LUNAR is developed in 1978 by W.A woods; it could analyze, compare and evaluate the chemical data on a lunar rock and soil composition that was accumulating as a result of Apollo moon missions and can answer the related questions.
Until 1990 NLP Evolved in a Rule Based Approaches. Where the we needed to write code for each and every structure and rule of a language. These Systems Need a Lot of lines and Dictionaries to be efficient this was an arduous task with diminishing returns. Then the Era of Statistical NLP came (Machine Learning) here the researchers used text to train the system to identify the different nuances in language. This method also need some supervision to fine-tune its final state but. This way WE can Create More efficient and Accurate NLP software and Approaches. 
With the increase of parallelized computational Power (Graphical Processing Units) the field of Machine Learning and Artificial Neural Networks are starting to show accuracy’s and efficiencies leaps and bounds ahead of the Traditional Approaches. This will only evolve and advance more as the time goes on. Currently Using the Available Toolkits/ libraries like NLTK anyone with the knowledge can create a NLP system with few line of code. We can see systems Like IBM Watson Which won the Jeopardy match in 2011 And Personal Assistants like Amazon Alexa and Google Now that uses NLP for Practical Real World applications. We also see Chabot’s, Language Translators, Voice Commanding and many more applications of NLP in the world Around Us. This was all due to the advancements of Natural Language Processing and Artificial Intelligence.

"""

# %%
type(data_in)
# Out:
# str

# %%
from nltk.tokenize import word_tokenize

# %%
data_in_tokens = word_tokenize(data_in)
data_in_tokens
# Out:
# ['Natural',
#  'Language',
#  'Started',
#  'as',
#  'a',
#  'Project',
#  'for',
#  'Translating',
#  'Languages',
#  'Mainly',
#  'Russian',
#  'in',
#  'to',
#  'English',
#  'in',
#  '1950',
#  '’',
#  's',
#  '.',
#  'Then',
#  'in',
#  '1954',
#  'in',
#  'a',
#  'Demonstrating',
#  'by',
#  'IBM',
#  'they',
#  'converted',
#  '60',
#  'Russian',
#  'Sentences',
#  'to',
#  'English',
#  'using',
#  'IBM-701',
#  'computer',
#  '.',
#  'The',
#  'Method',
#  'they',
#  'used',
#  'was',
#  'Computational',
#  'Linguistics',
#  'a',
#  'Combination',
#  'of',
#  'Statistics',
#  'and',
#  'Rules',
#  'of',
#  'Language',
#  '.',
#  'In',
#  '1956',
#  'in',
#  'a',
#  'Conference',
#  'that',
#  'were',
#  'held',
#  'in',
#  'Dartmouth',
#  'College',
#  ',',
#  'New',
#  'Hampshire',
#  ',',
#  'England',
#  'John',
#  'McCarthy',
#  'coined',
#  'the',
#  'Term',
#  '‘',
#  'Artificial',
#  'Intelligence',
#  '’',
#  '.',
#  'So',
#  'Natural',
#  'Language',
# ...

# %%
len(data_in_tokens)
# Out:
# 642

# %%
from nltk.probability import FreqDist
fredist = FreqDist()

# %%
for word in data_in_tokens:
    fredist[word.lower()]+=1
fredist
# Out:
# FreqDist({'the': 31, '.': 28, 'in': 25, 'and': 24, 'a': 20, 'of': 19, 'to': 18, 'language': 12, ',': 12, 'nlp': 12, ...})

# %%
fredist_top10 = fredist.most_common(10)
fredist_top10
# Out:
# [('the', 31),
#  ('.', 28),
#  ('in', 25),
#  ('and', 24),
#  ('a', 20),
#  ('of', 19),
#  ('to', 18),
#  ('language', 12),
#  (',', 12),
#  ('nlp', 12)]

# %%
from nltk.tokenize import blankline_tokenize
data_blankline = blankline_tokenize(data_in)
len(data_blankline)
# Out:
# 1

# %%
from nltk.util import bigrams,ngrams,trigrams

# %%
string = 'The Best and the Most Beautiful in the World cannot Be seen or even touched, they must be felt with the heart'
quotes_tokens = nltk.word_tokenize(string)
quotes_tokens
# Out:
# ['The',
#  'Best',
#  'and',
#  'the',
#  'Most',
#  'Beautiful',
#  'in',
#  'the',
#  'World',
#  'can',
#  'not',
#  'Be',
#  'seen',
#  'or',
#  'even',
#  'touched',
#  ',',
#  'they',
#  'must',
#  'be',
#  'felt',
#  'with',
#  'the',
#  'heart']

# %%
quotes_bigrams = list(nltk.bigrams(quotes_tokens))
quotes_bigrams
# Out:
# [('The', 'Best'),
#  ('Best', 'and'),
#  ('and', 'the'),
#  ('the', 'Most'),
#  ('Most', 'Beautiful'),
#  ('Beautiful', 'in'),
#  ('in', 'the'),
#  ('the', 'World'),
#  ('World', 'can'),
#  ('can', 'not'),
#  ('not', 'Be'),
#  ('Be', 'seen'),
#  ('seen', 'or'),
#  ('or', 'even'),
#  ('even', 'touched'),
#  ('touched', ','),
#  (',', 'they'),
#  ('they', 'must'),
#  ('must', 'be'),
#  ('be', 'felt'),
#  ('felt', 'with'),
#  ('with', 'the'),
#  ('the', 'heart')]

# %%
quotes_trigrams = list(nltk.trigrams(quotes_tokens))
quotes_trigrams
# Out:
# [('The', 'Best', 'and'),
#  ('Best', 'and', 'the'),
#  ('and', 'the', 'Most'),
#  ('the', 'Most', 'Beautiful'),
#  ('Most', 'Beautiful', 'in'),
#  ('Beautiful', 'in', 'the'),
#  ('in', 'the', 'World'),
#  ('the', 'World', 'can'),
#  ('World', 'can', 'not'),
#  ('can', 'not', 'Be'),
#  ('not', 'Be', 'seen'),
#  ('Be', 'seen', 'or'),
#  ('seen', 'or', 'even'),
#  ('or', 'even', 'touched'),
#  ('even', 'touched', ','),
#  ('touched', ',', 'they'),
#  (',', 'they', 'must'),
#  ('they', 'must', 'be'),
#  ('must', 'be', 'felt'),
#  ('be', 'felt', 'with'),
#  ('felt', 'with', 'the'),
#  ('with', 'the', 'heart')]

# %%
# Separates in to N number of Word Collections
quotes_ngrams = list(nltk.ngrams(quotes_tokens, 5))
quotes_ngrams
# Out:
# [('The', 'Best', 'and', 'the', 'Most'),
#  ('Best', 'and', 'the', 'Most', 'Beautiful'),
#  ('and', 'the', 'Most', 'Beautiful', 'in'),
#  ('the', 'Most', 'Beautiful', 'in', 'the'),
#  ('Most', 'Beautiful', 'in', 'the', 'World'),
#  ('Beautiful', 'in', 'the', 'World', 'can'),
#  ('in', 'the', 'World', 'can', 'not'),
#  ('the', 'World', 'can', 'not', 'Be'),
#  ('World', 'can', 'not', 'Be', 'seen'),
#  ('can', 'not', 'Be', 'seen', 'or'),
#  ('not', 'Be', 'seen', 'or', 'even'),
#  ('Be', 'seen', 'or', 'even', 'touched'),
#  ('seen', 'or', 'even', 'touched', ','),
#  ('or', 'even', 'touched', ',', 'they'),
#  ('even', 'touched', ',', 'they', 'must'),
#  ('touched', ',', 'they', 'must', 'be'),
#  (',', 'they', 'must', 'be', 'felt'),
#  ('they', 'must', 'be', 'felt', 'with'),
#  ('must', 'be', 'felt', 'with', 'the'),
#  ('be', 'felt', 'with', 'the', 'heart')]

# %% [markdown]
# <h2>Stemming</h2>
# <p>Normalize Word in to Base form <br>
# eg: walking to walk
# affetion to affect</p>

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()

# %%
pst.stem('having')
# Out:
# 'have'

# %%
words_stem = ['give','giving','given','gave']
for word in words_stem:
    print(word + ":" + pst.stem(word))
# Out:
# give:give
# giving:give
# given:given
# gave:gave

# %%
from nltk.stem  import LancasterStemmer
lst = LancasterStemmer()

for word in words_stem:
    print(word + ":" + lst.stem(word))
# Out:
# give:giv
# giving:giv
# given:giv
# gave:gav

# %% [markdown]
# <h2>Lematization</h2>
# <p>
# Groups Differnt Formes of words to root word (This Is called Lemma) <br>
#     Needs a Dictionary <br>
#     simmiler to Stemming <br>
#     output is a proper Word <br>
#     eg: Gone, going --> go
#
#
# </p>

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
word_len = WordNetLemmatizer()

# %%
for word in words_stem:
    print(word + ':'+ word_len.lemmatize(word))
# Out:
# give:give
# giving:giving
# given:given
# gave:gave

# %%
word_len.lemmatize('corpura')
# Out:
# 'corpura'

# %% [markdown]
# <h2>Stop Words </h2>
# <p>Normally Needed In the commen lanhuage to make sense of the text <br>
# useless in NLP</p>

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
fredist_top10
# Out:
# [('the', 31),
#  ('.', 28),
#  ('in', 25),
#  ('and', 24),
#  ('a', 20),
#  ('of', 19),
#  ('to', 18),
#  ('language', 12),
#  (',', 12),
#  ('nlp', 12)]

# %%
import re
punctuation =re.compile(r'[,.!?:;()|0-9]')

# %%
post_punctuation = []
for words in data_in_tokens:
    word = punctuation.sub("",words)
    if len(word)>0:
        post_punctuation.append(word)
        
post_punctuation
# Out:
# ['Natural',
#  'Language',
#  'Started',
#  'as',
#  'a',
#  'Project',
#  'for',
#  'Translating',
#  'Languages',
#  'Mainly',
#  'Russian',
#  'in',
#  'to',
#  'English',
#  'in',
#  '’',
#  's',
#  'Then',
#  'in',
#  'in',
#  'a',
#  'Demonstrating',
#  'by',
#  'IBM',
#  'they',
#  'converted',
#  'Russian',
#  'Sentences',
#  'to',
#  'English',
#  'using',
#  'IBM-',
#  'computer',
#  'The',
#  'Method',
#  'they',
#  'used',
#  'was',
#  'Computational',
#  'Linguistics',
#  'a',
#  'Combination',
#  'of',
#  'Statistics',
#  'and',
#  'Rules',
#  'of',
#  'Language',
#  'In',
#  'in',
#  'a',
#  'Conference',
#  'that',
#  'were',
#  'held',
#  'in',
#  'Dartmouth',
#  'College',
#  'New',
#  'Hampshire',
#  'England',
#  'John',
#  'McCarthy',
#  'coined',
#  'the',
#  'Term',
#  '‘',
#  'Artificial',
#  'Intelligence',
#  '’',
#  'So',
#  'Natural',
#  'Language',
#  'Processing',
#  'was',
#  'introduced',
#  'in',
#  'the',
#  'early',
#  'stages',
#  'of',
# ...

# %%
len(post_punctuation)
# Out:
# 581

# %% [markdown]
# <h2>Parts Of Speach</h2>

# %% [markdown]
#  <p>Tagging the WOrds with data line Noun, verb etc</p>

# %%
sent = 'Timothey is a natural when it comes to drowing'
sent_tokens = word_tokenize(sent)
for token in sent_tokens:
    print(nltk.pos_tag([token]))
# Out:
# [('Timothey', 'NN')]
# [('is', 'VBZ')]
# [('a', 'DT')]
# [('natural', 'JJ')]
# [('when', 'WRB')]
# [('it', 'PRP')]
# [('comes', 'VBZ')]
# [('to', 'TO')]
# [('drowing', 'VBG')]

# %% [markdown]
# <h2>Named Entity Recognition</h2>
# <p>is a name or place or <br>
# Classification of Nouns</p>

# %%
from nltk import ne_chunk

# %%
ne_sent ='the US Precident stays in the white house'

# %%
ne_tokens = word_tokenize(ne_sent)
ne_tags = nltk.pos_tag(ne_tokens)

# %%
ne_ner = ne_chunk(ne_tags)
print(ne_ner)
# Out:
# (S
#   the/DT
#   (ORGANIZATION US/NNP)
#   Precident/NNP
#   stays/VBZ
#   in/IN
#   the/DT
#   white/JJ
#   house/NN)

# %% [markdown]
# <h2>Syntax</h2>
# <p>Structure of the language Rules </p>

# %%
# Chunking Groping of words and tokens in to chunks
new = "The Big cat ate the little mouse who was after fresh clothes"
new_tokens = nltk.pos_tag(word_tokenize(new))
new_tokens
# Out:
# [('The', 'DT'),
#  ('Big', 'NNP'),
#  ('cat', 'NN'),
#  ('ate', 'VBD'),
#  ('the', 'DT'),
#  ('little', 'JJ'),
#  ('mouse', 'NN'),
#  ('who', 'WP'),
#  ('was', 'VBD'),
#  ('after', 'IN'),
#  ('fresh', 'JJ'),
#  ('clothes', 'NNS')]

# %%
gramer_np = r"NP: {<DT>?<JJ>*<NN>}"

# %%
chunl_parser = nltk.RegexpParser(gramer_np)

# %%
chunk_result =
# Out:
# <chunk.RegexpParser with 1 stages>
